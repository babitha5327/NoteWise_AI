# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-2e2635d6-27a6-4811-9d77-d95ed1427441" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2e2635d6-27a6-4811-9d77-d95ed1427441">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import zipfile

zip_file = list(uploaded.keys())[0]

with zipfile.ZipFile(zip_file, "r") as zip_ref:
    zip_ref.extractall("/content")

print("Project extracted successfully!")
# Out:
# Project extracted successfully!

# %%
# !pip install -q pytesseract pillow pypdf python-docx gTTS deep-translator flask

# %%
# !apt-get update -qq
# !apt-get install -y -qq tesseract-ocr
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)

# %%
# %cd /content/NoteWiseAI/backend
# Out:
# /content/NoteWiseAI/backend

# %%
# !pip install -q pyngrok

# %%
from pyngrok import ngrok, conf
import getpass

token = getpass.getpass("Enter your ngrok Authtoken: ")
conf.get_default().auth_token = token
# Out:
# Enter your ngrok Authtoken: ··········

# %%
# !nohup python final_server.py > /tmp/notewise.log 2>&1 &

# %%
# !cat /tmp/notewise.log
# Out:
# [NoteWiseAI] NumExpr defaulting to 2 threads.
# ...
# NOTEWISE AI - starting
# ...
# OCR (tesseract):        AVAILABLE
# Project OCR service:    not found (using tesseract)
# Project note pipeline:  not found (using local fallback)
# PDF support (pypdf):    AVAILABLE
# DOCX support:           AVAILABLE
# Server TTS (gTTS):      AVAILABLE
# Translation service:    AVAILABLE
# ...
#  * Serving Flask app 'final_server'
#  * Debug mode: off
# Address already in use
# Port 7860 is in use by another program. Either identify and stop that program, or start the server with a different port.

# %%
from pyngrok import ngrok

tunnel = ngrok.connect(7860, "http")

print("====================================")
print("NOTEWISE AI PUBLIC URL")
print("====================================")
print(tunnel.public_url)
# Out:
# ...
# NOTEWISE AI PUBLIC URL
# ...
# https://happiness-shorten-shanty.ngrok-free.dev

# %%
from pyngrok import ngrok

ngrok.kill()
print("Old ngrok tunnel stopped.")
# Out:
# Old ngrok tunnel stopped.

# %%
# %cd /content/NoteWiseAI/backend

# !nohup python final_server.py > /tmp/notewise.log 2>&1 &
# Out:
# /content/NoteWiseAI/backend

# %%
# !cat /tmp/notewise.log
# Out:
# [NoteWiseAI] NumExpr defaulting to 2 threads.
# ...
# NOTEWISE AI - starting
# ...
# OCR (tesseract):        AVAILABLE
# Project OCR service:    not found (using tesseract)
# Project note pipeline:  not found (using local fallback)
# PDF support (pypdf):    AVAILABLE
# DOCX support:           AVAILABLE
# Server TTS (gTTS):      AVAILABLE
# Translation service:    AVAILABLE
# ...
#  * Serving Flask app 'final_server'
#  * Debug mode: off
# [NoteWiseAI] WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:7860
#  * Running on http://172.28.0.12:7860
# [NoteWiseAI] Press CTRL+C to quit

# %%
# !curl -I http://127.0.0.1:7860
# Out:
# HTTP/1.1 200 OK
# Server: Werkzeug/3.1.8 Python/3.12.13
# Date: Fri, 14 Aug 2026 07:37:29 GMT
# Content-Type: text/html; charset=utf-8
# Content-Length: 10219
# Connection: close

# %%
from pyngrok import ngrok

tunnel = ngrok.connect(7860)
print("PUBLIC URL:")
print(tunnel.public_url)
# Out:
# PUBLIC URL:
# https://happiness-shorten-shanty.ngrok-free.dev
